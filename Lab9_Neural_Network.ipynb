# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/Machine-Learning-/blob/main/Lab9_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network to Implement using AND

# %%
# import Python Libraries
import numpy as np
from matplotlib import pyplot as plt

# Sigmoid Function
def sigmoid(z):
	return 1 / (1 + np.exp(-z))

# Initialization of the neural network parameters
# Initialized all the weights in the range of between 0 and 1
# Bias values are initialized to 0
def initializeParameters(inputFeatures, neuronsInHiddenLayers, outputFeatures):
	W1 = np.random.randn(neuronsInHiddenLayers, inputFeatures)
	W2 = np.random.randn(outputFeatures, neuronsInHiddenLayers)
	b1 = np.zeros((neuronsInHiddenLayers, 1))
	b2 = np.zeros((outputFeatures, 1))
	
	parameters = {"W1" : W1, "b1": b1,
				"W2" : W2, "b2": b2}
	return parameters

# Forward Propagation
def forwardPropagation(X, Y, parameters):
	m = X.shape[1]
	W1 = parameters["W1"]
	W2 = parameters["W2"]
	b1 = parameters["b1"]
	b2 = parameters["b2"]

	Z1 = np.dot(W1, X) + b1
	A1 = sigmoid(Z1)
	Z2 = np.dot(W2, A1) + b2
	A2 = sigmoid(Z2)

	cache = (Z1, A1, W1, b1, Z2, A2, W2, b2)
	logprobs = np.multiply(np.log(A2), Y) + np.multiply(np.log(1 - A2), (1 - Y))
	cost = -np.sum(logprobs) / m
	return cost, cache, A2

# Backward Propagation
def backwardPropagation(X, Y, cache):
	m = X.shape[1]
	(Z1, A1, W1, b1, Z2, A2, W2, b2) = cache
	
	dZ2 = A2 - Y
	dW2 = np.dot(dZ2, A1.T) / m
	db2 = np.sum(dZ2, axis = 1, keepdims = True)
	
	dA1 = np.dot(W2.T, dZ2)
	dZ1 = np.multiply(dA1, A1 * (1- A1))
	dW1 = np.dot(dZ1, X.T) / m
	db1 = np.sum(dZ1, axis = 1, keepdims = True) / m
	
	gradients = {"dZ2": dZ2, "dW2": dW2, "db2": db2,
				"dZ1": dZ1, "dW1": dW1, "db1": db1}
	return gradients

# Updating the weights based on the negative gradients
def updateParameters(parameters, gradients, learningRate):
	parameters["W1"] = parameters["W1"] - learningRate * gradients["dW1"]
	parameters["W2"] = parameters["W2"] - learningRate * gradients["dW2"]
	parameters["b1"] = parameters["b1"] - learningRate * gradients["db1"]
	parameters["b2"] = parameters["b2"] - learningRate * gradients["db2"]
	return parameters

# Model to learn the AND truth table
X = np.array([[0, 0, 1, 1], [0, 1, 0, 1]]) # AND input
Y = np.array([[0, 0, 0, 1]]) # AND output

# Define model parameters
neuronsInHiddenLayers = 2 # number of hidden layer neurons (2)
inputFeatures = X.shape[0] # number of input features (2)
outputFeatures = Y.shape[0] # number of output features (1)
parameters = initializeParameters(inputFeatures, neuronsInHiddenLayers, outputFeatures)
epoch = 100000
learningRate = 0.01
losses = np.zeros((epoch, 1))

for i in range(epoch):
	losses[i, 0], cache, A2 = forwardPropagation(X, Y, parameters)
	gradients = backwardPropagation(X, Y, cache)
	parameters = updateParameters(parameters, gradients, learningRate)

# Evaluating the performance
plt.figure()
plt.plot(losses)
plt.xlabel("EPOCHS")
plt.ylabel("Loss value")
plt.show()

# Testing
X = np.array([[1, 1, 0, 0], [0, 1, 0, 1]]) # AND input
cost, _, A2 = forwardPropagation(X, Y, parameters)
prediction = (A2 > 0.5) * 1.0
# print(A2)
print(prediction)
# Out:
# [[0. 1. 0. 0.]]

# %% [markdown]
# # Implementation of Artificial Neural Network for XOR Logic Gate

# %%
# import Python Libraries
import numpy as np
from matplotlib import pyplot as plt

# Sigmoid Function
def sigmoid(z):
	return 1 / (1 + np.exp(-z))

# Initialization of the neural network parameters
# Initialized all the weights in the range of between 0 and 1
# Bias values are initialized to 0
def initializeParameters(inputFeatures, neuronsInHiddenLayers, outputFeatures):
	W1 = np.random.randn(neuronsInHiddenLayers, inputFeatures)
	W2 = np.random.randn(outputFeatures, neuronsInHiddenLayers)
	b1 = np.zeros((neuronsInHiddenLayers, 1))
	b2 = np.zeros((outputFeatures, 1))
	
	parameters = {"W1" : W1, "b1": b1,
				"W2" : W2, "b2": b2}
	return parameters

# Forward Propagation
def forwardPropagation(X, Y, parameters):
	m = X.shape[1]
	W1 = parameters["W1"]
	W2 = parameters["W2"]
	b1 = parameters["b1"]
	b2 = parameters["b2"]

	Z1 = np.dot(W1, X) + b1
	A1 = sigmoid(Z1)
	Z2 = np.dot(W2, A1) + b2
	A2 = sigmoid(Z2)

	cache = (Z1, A1, W1, b1, Z2, A2, W2, b2)
	logprobs = np.multiply(np.log(A2), Y) + np.multiply(np.log(1 - A2), (1 - Y))
	cost = -np.sum(logprobs) / m
	return cost, cache, A2

# Backward Propagation
def backwardPropagation(X, Y, cache):
	m = X.shape[1]
	(Z1, A1, W1, b1, Z2, A2, W2, b2) = cache
	
	dZ2 = A2 - Y
	dW2 = np.dot(dZ2, A1.T) / m
	db2 = np.sum(dZ2, axis = 1, keepdims = True)
	
	dA1 = np.dot(W2.T, dZ2)
	dZ1 = np.multiply(dA1, A1 * (1- A1))
	dW1 = np.dot(dZ1, X.T) / m
	db1 = np.sum(dZ1, axis = 1, keepdims = True) / m
	
	gradients = {"dZ2": dZ2, "dW2": dW2, "db2": db2,
				"dZ1": dZ1, "dW1": dW1, "db1": db1}
	return gradients

# Updating the weights based on the negative gradients
def updateParameters(parameters, gradients, learningRate):
	parameters["W1"] = parameters["W1"] - learningRate * gradients["dW1"]
	parameters["W2"] = parameters["W2"] - learningRate * gradients["dW2"]
	parameters["b1"] = parameters["b1"] - learningRate * gradients["db1"]
	parameters["b2"] = parameters["b2"] - learningRate * gradients["db2"]
	return parameters

# Model to learn the XOR truth table
X = np.array([[0, 0, 1, 1], [0, 1, 0, 1]]) # XOR input
Y = np.array([[0, 1, 1, 0]]) # XOR output

# Define model parameters
neuronsInHiddenLayers = 2 # number of hidden layer neurons (2)
inputFeatures = X.shape[0] # number of input features (2)
outputFeatures = Y.shape[0] # number of output features (1)
parameters = initializeParameters(inputFeatures, neuronsInHiddenLayers, outputFeatures)
epoch = 100000
learningRate = 0.01
losses = np.zeros((epoch, 1))

for i in range(epoch):
	losses[i, 0], cache, A2 = forwardPropagation(X, Y, parameters)
	gradients = backwardPropagation(X, Y, cache)
	parameters = updateParameters(parameters, gradients, learningRate)

# Evaluating the performance
plt.figure()
plt.plot(losses)
plt.xlabel("EPOCHS")
plt.ylabel("Loss value")
plt.show()

# Testing
X = np.array([[1, 1, 0, 0], [0, 1, 0, 1]]) # XOR input
cost, _, A2 = forwardPropagation(X, Y, parameters)
prediction = (A2 > 0.5) * 1.0
# print(A2)
print(prediction)
# Out:
# [[1. 0. 0. 1.]]

# %% [markdown]
# # Implementing in the my own data set

# %%
#Importing necessary Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
# Reading the dataset
diabetesdata = pd.read_csv('/content/sample_data/diabetes.csv')
y = diabetesdata['Outcome']
X = diabetesdata.drop(['Outcome'],axis=1)

# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

#Performing Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
#Initializing ANN
ann = tf.keras.models.Sequential()
#Adding First Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))
#Adding Second Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))
#Adding Output Layer
ann.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
#Compiling ANN
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])
#Fitting ANN
ann.fit(X_train,y_train,batch_size=32,epochs = 100)
# Saving created neural network
ann.save("ANN.h5")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 0.7116 - accuracy: 0.5486
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5972
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.6441
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6453 - accuracy: 0.6580
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.6545
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6151 - accuracy: 0.6545
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6024 - accuracy: 0.6545
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.6562
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5805 - accuracy: 0.6580
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5698 - accuracy: 0.6580
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5612 - accuracy: 0.6580
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.6597
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.6667
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5371 - accuracy: 0.6701
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.6944
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.7135
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5178 - accuracy: 0.7274
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5125 - accuracy: 0.7378
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.7431
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5028 - accuracy: 0.7431
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.7517
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.7483
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4908 - accuracy: 0.7535
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7569
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.7604
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4808 - accuracy: 0.7639
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.7656
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4763 - accuracy: 0.7743
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.7726
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4717 - accuracy: 0.7708
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7743
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7795
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.7760
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.7847
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7865
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7865
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.7865
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7812
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7830
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4591 - accuracy: 0.7812
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7812
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4576 - accuracy: 0.7812
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.7812
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4561 - accuracy: 0.7812
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7812
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.7795
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7795
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.7760
# Epoch 49/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4529 - accuracy: 0.7778
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.7760
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.7778
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4508 - accuracy: 0.7795
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4503 - accuracy: 0.7830
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7812
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.7795
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7812
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.7830
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7830
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.7847
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.7847
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7847
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.7847
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7865
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.7865
# Epoch 65/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4439 - accuracy: 0.7830
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4433 - accuracy: 0.7830
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7812
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.7830
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7865
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.7882
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7882
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.7899
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4406 - accuracy: 0.7899
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7917
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.7899
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7899
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.7882
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.7882
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.7882
# Epoch 80/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.7882
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.7882
# Epoch 82/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4374 - accuracy: 0.7865
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7882
# Epoch 84/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.7899
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.7899
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7882
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.7865
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.7847
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7865
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4353 - accuracy: 0.7847
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.7847
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.7865
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.7882
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.7847
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.7899
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.7865
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.7917
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.7934
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.7917
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7865
