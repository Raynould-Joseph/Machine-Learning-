# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/Machine-Learning-/blob/main/ML_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6448d350-2659-4bdd-85c1-d103c612501f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6448d350-2659-4bdd-85c1-d103c612501f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exoplanet_confirm_and_candidates.csv to exoplanet_confirm_and_candidates.csv

# %%
# import pandas module
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/ML Lab/exoplanet_confirm_and_candidates.csv')
df = df.replace(np.nan, 0)
df.replace([np.inf, -np.inf], 0, inplace=True)

# %%
# Python program to illustrate
# creating a data frame using CSV files
 
# import pandas module
import pandas as pd
import numpy as np
 
# creating a data frame
df = pd.read_csv("exoplanet_confirm_and_candidates.csv")
df = df.replace(np.nan, 0)
df.replace([np.inf, -np.inf], 0, inplace=True)

print(df.head)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-5ab438b6c582> in <module>()
#       7
#       8 # creating a data frame
# ----> 9 df = pd.read_csv("exoplanet_confirm_and_candidates.csv")
#      10 df = df.replace(np.nan, 0)
#      11 df.replace([np.inf, -np.inf], 0, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# round off for pont values

# %%
df.star_age=df.star_age.round()
print (df.star_age)
# Out:
# 0       0.0
# 1       0.0
# 2       2.0
# 3       0.0
# 4       0.0
#        ...
# 7409    4.0
# 7410    4.0
# 7411    4.0
# 7412    4.0
# 7413    1.0
# Name: star_age, Length: 7414, dtype: float64

# %%
df.star_age_error_min=df.star_age_error_min.round()
print (df.star_age_error_min)
# Out:
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 7409    1.0
# 7410    1.0
# 7411    1.0
# 7412    1.0
# 7413    0.0
# Name: star_age_error_min, Length: 7414, dtype: float64

# %%
from google.colab import files

df.to_csv('output.csv', encoding = 'utf-8-sig') 
files.download('output.csv')

# %%
import matplotlib.pyplot as plt 
import numpy
import pickle
from sklearn.linear_model import LinearRegression 
x = df['star_age']
y = df['mass_error_min']
model = LinearRegression()
model.fit(x.values.reshape(-1,1), y) 
plt.figure()
plt.title('Star Age statistics')
plt.xlabel('Star age  (mollons)')
plt.ylabel('star age error min (millons)')
plt.plot(x,y,'.')
plt.plot(x.predict(x),'--')
plt.axis([0,1,0,1])
plt.grid(True) 
print ("Predicted price = ",model.predict([[5]])) # 22.467
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-209533744d3a> in <module>()
#      12 plt.ylabel('star age error min (millons)')
#      13 plt.plot(x,y,'.')
# ---> 14 plt.plot(x.predict(x),'--')
#      15 plt.axis([0,1,0,1])
#      16 plt.grid(True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'predict'

# %% [markdown]
# **Mutiple Regression**

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import lstsq
import numpy as np
x = [[6, 2], [8, 1], [10, 0], [14, 2], [18, 0]]
y = [[7], [9], [13], [17.5], [18]]
model = LinearRegression()
model.fit(x,y)
x1 = [[8, 2], [9, 0], [11, 2], [16, 2], [12, 0]]
y1 = [[11], [8.5], [15], [18], [11]]
predictions = model.predict([[8, 2], [9, 0], [12, 0]])
print ("values of Predictions:",predictions)
print ("values of β1, β2:",lstsq(x, y, rcond=None)[0])
#least-squares solution to find best regression line
#It is a cut-off ratio for smaller singular values of x and Y
print ("Score =",model.score(x1, y1))
# Out:
# values of Predictions: [[10.0625 ]
#  [10.28125]
#  [13.3125 ]]
# values of β1, β2: [[1.08548851]
#  [0.65517241]]
# Score = 0.7701677731318468

# %%
import numpy as np
import matplotlib.pyplot  as plot
import pandas as pd
from scipy import stats
pd = pd.read_csv("exoplanet_confirm_and_candidates.csv")
features = pd["star_age"]
labels = pd["mass_error_min"]
slope, intercept, r, p, std_err = stats.linregress(features, labels)
def lineFunc(x):
  return slope * x + intercept
lineY = list(map(lineFunc, features))
print(lineY)

plot.scatter(features,labels)
plot.plot(features,lineY)
plot.show()
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, na
# ...

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as mpt

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8d1f1d4-4eb5-4131-b81a-18718beb63e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8d1f1d4-4eb5-4131-b81a-18718beb63e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving output.csv to output (1).csv

# %%
data_set= pd.read_csv('output.csv',encoding='cp1252')

# %%
data_set
# Out:
#        ï»¿     # name planet_status   mass  mass_error_min  mass_error_max  \
# 0        0   11 Com b     Confirmed   0.00            0.00            0.00
# 1        1   11 Oph b     Confirmed  21.00            3.00            3.00
# 2        2   11 UMi b     Confirmed   0.00            0.00            0.00
# 3        3   11 Uma b   Unconfirmed   3.72            0.82            0.82
# 4        4   14 And b     Confirmed   0.00            0.00            0.00
# ...    ...        ...           ...    ...             ...             ...
# 7409  7409  ups And b     Confirmed   0.62            0.09            0.00
# 7410  7410  ups And c     Confirmed   9.10            2.93            5.04
# 7411  7411  ups And d     Confirmed  23.58            2.29            2.93
# 7412  7412  ups And e     Confirmed   0.00            0.00            0.00
# 7413  7413  zet Del B     Confirmed  40.00            5.00           15.00
#
# ...

# %%
kerala=data_set[data_set["planet_status"]=="Confirmed"]

# %%
locations = kerala['# name']
for i in locations:
    print(i)
# Out:
# 11 Com b
# 11 Oph b
# 11 UMi b
# 14 And b
# 14 Her b
# 16 Cyg B b
# 17 Sco b
# 18 Del b
# 1I/'Oumuamua
# 1RXS 1609 b
# 1RXS J235133.3+312720 b
# 1SWASP J1407 b
# 24 Boo b
# 24 Sex b
# 24 Sex c
# 2I/Borisov
# 2M 0103-55 (AB) b
# 2M 0122-24 b
# 2M 0219-39 b
# 2M 0441+23 b
# 2M 1938+46 b
# 2M 2140+16 b
# 2M 2206-20 b
# 2M 2236+4751 b
# 2M J2126-81 b
# 2M0045+16
# 2M0117-34
# 2M1059-21 b
# 2M1207 A
# 2M1207 b
# 2M1510A a
# 2M1510A b
# 2MASS J00413538-5621127 A
# 2MASS J00413538-5621127 B
# 2MASS J0249-0557 (AB) c
# 2MASS J0249-0557A
# 2MASS J0249-0557B
# 2MASS J0348-6022
# 2MASS J0407+1546
# 2MASS J10475385+2124234
# 2MASS J11011926-7732383 A
# 2MASS J11011926-7732383 B
# 2MASS J11193254 AB
# 2MASS J1155-7919 b
# 2MASS J1219+3128
# 2MASS J1450-7841 A
# 2MASS J1450-7841 B
# 2MASS J15344984-2952274 A
# 2MASS J15344984-2952274 B
# 2MASS J2250+2325 b
# 3 Cnc b
# 30 Ari B b
# 38 Vir b
# 4 Uma b
# 42 Dra b
# 44 Uma b
# 47 Uma b
# 47 Uma c
# 47 Uma d
# 51 Eri b
# 51 Peg b
# 55 Cnc b
# 55 Cnc c
# ...

# %%
locations = kerala['# name']
for i in locations:
    print(i)
# Out:
# 11 Com b
# 11 Oph b
# 11 UMi b
# 14 And b
# 14 Her b
# 16 Cyg B b
# 17 Sco b
# 18 Del b
# 1I/'Oumuamua
# 1RXS 1609 b
# 1RXS J235133.3+312720 b
# 1SWASP J1407 b
# 24 Boo b
# 24 Sex b
# 24 Sex c
# 2I/Borisov
# 2M 0103-55 (AB) b
# 2M 0122-24 b
# 2M 0219-39 b
# 2M 0441+23 b
# 2M 1938+46 b
# 2M 2140+16 b
# 2M 2206-20 b
# 2M 2236+4751 b
# 2M J2126-81 b
# 2M0045+16
# 2M0117-34
# 2M1059-21 b
# 2M1207 A
# 2M1207 b
# 2M1510A a
# 2M1510A b
# 2MASS J00413538-5621127 A
# 2MASS J00413538-5621127 B
# 2MASS J0249-0557 (AB) c
# 2MASS J0249-0557A
# 2MASS J0249-0557B
# 2MASS J0348-6022
# 2MASS J0407+1546
# 2MASS J10475385+2124234
# 2MASS J11011926-7732383 A
# 2MASS J11011926-7732383 B
# 2MASS J11193254 AB
# 2MASS J1155-7919 b
# 2MASS J1219+3128
# 2MASS J1450-7841 A
# 2MASS J1450-7841 B
# 2MASS J15344984-2952274 A
# 2MASS J15344984-2952274 B
# 2MASS J2250+2325 b
# 3 Cnc b
# 30 Ari B b
# 38 Vir b
# 4 Uma b
# 42 Dra b
# 44 Uma b
# 47 Uma b
# 47 Uma c
# 47 Uma d
# 51 Eri b
# 51 Peg b
# 55 Cnc b
# 55 Cnc c
# ...

# %%
locations_list=locations.to_list
locations
# Out:
# 0        11 Com b
# 1        11 Oph b
# 2        11 UMi b
# 4        14 And b
# 5        14 Her b
#           ...
# 7409    ups And b
# 7410    ups And c
# 7411    ups And d
# 7412    ups And e
# 7413    zet Del B
# Name: # name, Length: 4718, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
locations = kerala['# name']
ph = kerala['star_age']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(locations[0:10], ph[0:10])
 
# Show Plot
plt.show()

# %%
locations = kerala['# name']
ph = kerala['star_age']
 
# Figure Size
fig, ax = plt.subplots(figsize =(6,9))
 
# Horizontal Bar Plot
ax.barh(locations[1:20], ph[1:20])
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 2)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Age of star in billons',
             loc ='left', )
 
# # Add Text watermark
# fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
#          color ='grey', ha ='right', va ='bottom',
#          alpha = 0.7)
 
# Show Plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plot=sns.distplot(kerala.star_age,kde=False,color="b")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
   
age1=kerala['star_age'].dropna()
sns.distplot(age1)         
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
collectn_1 = kerala['star_age']
collectn_2 = kerala['mass']


## combine these different collections into a list
data_to_plot = [collectn_1, collectn_2]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])

# Create the boxplot
bp = ax.violinplot(data_to_plot)
plt.show()
