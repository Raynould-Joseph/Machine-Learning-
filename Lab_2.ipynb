# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/Machine-Learning-/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas module
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/ML Lab/sample50.csv')
df = df.replace(np.nan, 0)
df.replace([np.inf, -np.inf], 0, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0                       # name planet_status   mass  \
# 0            0                     11 Com b     Confirmed   0.00
# 1            1                     11 Oph b     Confirmed  21.00
# 2            2                     11 UMi b     Confirmed   0.00
# 3            3                     11 Uma b   Unconfirmed   3.72
# 4            4                     14 And b     Confirmed   0.00
# 5            5                     14 Her b     Confirmed   0.00
# 6            6                     14 Her c   Unconfirmed   2.10
# 7            7                   16 Cyg B b     Confirmed   0.00
# 8            8                     17 Sco b     Confirmed   0.00
# 9            9                     18 Del b     Confirmed   0.00
# 10          10                 19b1-02162 b   Unconfirmed   0.00
# 11          11                 1I/'Oumuamua     Confirmed   0.00
# 12          12                  1RXS 1609 b     Confirmed  14.00
# ...

# %%
dataset= pd.read_csv('/content/gdrive/MyDrive/ML Lab/sample50.csv')
dataset
# Out:
#     Unnamed: 0                       # name planet_status   mass  \
# 0            0                     11 Com b     Confirmed    NaN
# 1            1                     11 Oph b     Confirmed  21.00
# 2            2                     11 UMi b     Confirmed    NaN
# 3            3                     11 Uma b   Unconfirmed   3.72
# 4            4                     14 And b     Confirmed    NaN
# 5            5                     14 Her b     Confirmed    NaN
# 6            6                     14 Her c   Unconfirmed   2.10
# 7            7                   16 Cyg B b     Confirmed    NaN
# 8            8                     17 Sco b     Confirmed    NaN
# 9            9                     18 Del b     Confirmed    NaN
# 10          10                 19b1-02162 b   Unconfirmed    NaN
# 11          11                 1I/'Oumuamua     Confirmed    NaN
# 12          12                  1RXS 1609 b     Confirmed  14.00
# ...

# %%
X = dataset.iloc[:, 0:2] .values
y = df.iloc[:,4].values

X
# Out:
# array([[0, '11 Com b'],
#        [1, '11 Oph b'],
#        [2, '11 UMi b'],
#        [3, '11 Uma b'],
#        [4, '14 And b'],
#        [5, '14 Her b'],
#        [6, '14 Her c'],
#        [7, '16 Cyg B b'],
#        [8, '17 Sco b'],
#        [9, '18 Del b'],
#        [10, '19b1-02162 b'],
#        [11, "1I/'Oumuamua"],
#        [12, '1RXS 1609 b'],
#        [13, '1RXS J235133.3+312720 b'],
#        [14, '1SWASP J1407 b'],
#        [15, '1SWASPJ115718.66+261906.1 b'],
#        [16, '1SWASPJ130322.00+350525.4 b'],
#        [17, '1SWASPJ152131.01+213521.3 b'],
#        [18, '1SWASPJ160242.43+290850.1 b'],
#        [19, '1SWASPJ161732.90+242119.0 b'],
#        [20, '21 Her (AB) b'],
#        [21, '24 Boo b'],
#        [22, '24 Sex b'],
#        [23, '24 Sex c'],
#        [24, '2I/Borisov'],
#        [25, '2M 0103-55 (AB) b'],
#        [26, '2M 0122-24 b'],
#        [27, '2M 0219-39 b'],
#        [28, '2M 0441+23 b'],
#        [29, '2M 1759-2739 b'],
#        [30, '2M 1938+46 b'],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-827227edc7c4> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a778cd74276d> in <module>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit(X_train)
#       4 X_train = scaler.transform(X_train)
#       5 X_test = scaler.transform(X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     845             dtype=FLOAT_DTYPES,
#     846             force_all_finite="allow-nan",
# ...

# %%
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
# define data

print(X_train)
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaler.fit(X_train)
scaled = scaler.fit_transform(X_train)
print(scaled)
# Out:
# [[33 '2M 2236+4751 b' 'Confirmed' ... 0.0 0.0 0.0]
#  [43 '2MASS J00413538-5621127 A' 'Confirmed' ... 0.0 0.0 0.0]
#  [46 '2MASS J0249-0557A' 'Confirmed' ... 0.0 0.0 0.0]
#  ...
#  [25 '2M 0103-55 (AB) b' 'Confirmed' ... 0.0 0.0 0.0]
#  [7 '16 Cyg B b' 'Confirmed' ... 60.0 0.0 0.0]
#  [9 '18 Del b' 'Confirmed' ... 18.0 0.0 0.0]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-20691690aa2c> in <module>()
#       7 scaler = MinMaxScaler()
#       8 # transform data
# ----> 9 scaler.fit(X_train)
#      10 scaled = scaler.fit_transform(X_train)
#      11 print(scaled)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     414         # Reset internal state before fitting
#     415         self._reset()
# --> 416         return self.partial_fit(X, y)
#     417
#     418     def partial_fit(self, X, y=None):
#
# ...
